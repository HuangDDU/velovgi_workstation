# %%
import pandas as pd
import gseapy as gp

# %%
gene_list = list(pd.read_csv("output/top100.csv", header=None)[0])

# %%
enrichment_df = gp.enrichr(gene_list, gene_sets="KEGG_2019_Mouse").res2d # kegg只需要搜索1个数据库即可
enrichment_df.to_csv("output/top100_kegg.csv") # 保存DataFrame
gp.dotplot(enrichment_df, figsize=(3,5)) # 保存kegg结果图
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/velovgi/lib/python3.8/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File ~/anaconda3/envs/velovgi/lib/python3.8/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File ~/anaconda3/envs/velovgi/lib/python3.8/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
#      86 return sock
# ...
